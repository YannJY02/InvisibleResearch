# %% [markdown]
# ## SCImago vs OpenAlex coverage (1999-2024) via ISSN OR Title
#
# This notebook adapts the owner command `research/scimago-openalex-coverage/analysis/coverage.py` to compute coverage of `$DATA_ROOT/processed/scimagojr_communication_journal_1999_2024.csv` against `$DATA_ROOT/processed/openalex_merged.parquet` using ISSN or normalized Title matching (no year filter).
#
# Outputs (to the owner's ignored `artifacts/` directory):
# - `scim_openalex_coverage_summary_1999_2024.csv`
# - `scim_openalex_unmatched_journals_1999_2024.csv`

# %%
# %run research/scimago-openalex-coverage/analysis/coverage.py --name-suffix 1999_2024
